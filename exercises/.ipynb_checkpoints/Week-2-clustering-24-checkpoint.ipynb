# %% [markdown]
# # Week 2 (K-means, K-medoids, Gaussian Mixtures)
#
# This week we are going to work with K-means, K-medoids, and Gaussian Mixtures.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Local imports (used for the last optional exercise.)
import math
import itertools
import sys
sys.path.append(".")
from utilities.load_data import load_iris, load_iris_PC, index_to_feature

# %% [markdown]
# ## Exercise 1: Warmup
# Please provide a brief description of what characterises
# 1. Clustering as a task
#    Group objects into subgroups.
# 2. Representative-based clustering as a clustering approach
#    First assign representants of each cluster and then assign each object to the cluster with the closest representant. Then calculate new representants and repeat until the change in representants between iterations is below a threshold.

# %% [markdown]
# ## Exercise 2: Practical K-means
# Given the following points: 2, 4, 10, 12, 3, 20, 30, 11, 25. Assume $k=3$, and that we randomly pick the initial means $\mu_1=2$, $ \mu_2=4$ and $\mu_3=6$. Show the clusters obtained using K-means algorithm after one iteration, and show the new means for the next iteration.

# %%
# You can use python if you want but it is not required!
X = np.array([2, 4, 10, 12, 3, 20, 30, 11, 25])
mu = np.array([2, 4, 6])

# Cluster assignment
clusters = []

for i in range(len(X)):
    dist_i = []
    
    for j in range(len(mu)):
        dist_i.append(np.linalg.norm(X[i] - mu[j]))
        
    closest = np.argmin(dist_i)
    clusters.append(closest)
    
print('Clusters: ', dist_i)

# New means
clust_len = [0] * len(mu)
clust_add = [0] * len(mu)

for i, cluster in enumerate(clusters):
    clust_add[cluster] += X[i]
    clust_len[cluster] += 1

for i in range(len(mu)):
    mu[i] = clust_add[i] / clust_len[i]

print('New means: ', mu)
# Out:
# Clusters:  [23.0, 21.0, 19.0]
# New means:  [ 2  4 18]

# %% [markdown]
# ## Exercise 3
# Which algorithm is more robust: k-means or k-medoid and why?
#
# k-medoid as it doesn't use mean but rather median, which is robust, to calculate the centroids.

# %% [markdown]
# ## Exercise 4: Practical Mixture of Gaussians
# Given the data points in table below, and their probability of belonging to two clusters.
# Assume that these points were produced by a mixture of two univariate normal distributions.
# Answer the following questions:
#
# 1. Find the maximum likelihood estimate of the means $\mu_1$ and $\mu_2$
# 2. Assume that $\mu_1 = 2$, $\mu_2 = 7$, and $\sigma_1 = \sigma_2 = 1$. Find the probability that the point $x=5$ belongs to cluster $C_1$ and to cluster $C_2$. You may assume that the prior probability of each cluster is equal (i.e., $P(C_1) = P(C_2) = 0.5$), and the prior probability $P(x=5) = 0.029$
#
# |$x$|$P(C_1\mid x)$|$P(C_2\mid x)$|
# |:---:|:---:|:---:|
# | --- | ---------------- | ---------------- |
# |2 |  0.9  |  0.1  |
# |3|0.8|0.2|
# |7|0.3|0.7|
# |9|0.1|0.9|
# |2|0.9|0.1|
# |1|0.8|0.2|

# %%
# If you want, you can use python here.
# Note that there is a
X            = np.array([2, 3, 7, 9, 2, 1])
P_C1_given_x = np.array([0.9, 0.8, 0.3, 0.1, 0.9, 0.8])
P_C2_given_x = 1 - P_C1_given_x

# TODO
# Task 1:
mu1 = np.sum([X[i] * P_C1_given_x[i] for i in range(len(X))]) / np.sum([P_C1_given_x[i] for i in range(len(X))])
mu2 = np.sum([X[i] * P_C2_given_x[i] for i in range(len(X))]) / np.sum([P_C2_given_x[i] for i in range(len(X))])

print('mu1: ', mu1)
print('mu2: ', mu2)

# Task 2:

P_x_given_C1 = norm.pdf(5, loc = 2, scale = 1)
P_x_given_C2 = norm.pdf(5, loc = 7, scale = 1)

P_C1_given_x_5 = (P_x_given_C1 * 0.5) / 0.029
P_C2_given_x_5 = (P_x_given_C2 * 0.5) / 0.029

print('P_C1_given_x_5: ', P_C1_given_x_5)
print('P_C2_given_x_5: ', P_C2_given_x_5)
# Out:
# mu1:  2.5789473684210535
# mu2:  6.454545454545453
# P_C1_given_x_5:  0.07641117951617254
# P_C2_given_x_5:  0.930878732986001

# %% [markdown]
# Using:
# ![image.png](attachment:19acb762-4728-48fc-9977-4d59d98b2fb1.png)![image.png](attachment:c775e6ef-b208-4058-98eb-31826b986271.png)
#
# where ![image.png](attachment:2a440ee2-c8f7-4fc4-8279-98cc40805d66.png)
#
# Which is calculated using norm.pdf.

# %% [markdown]
# ## Exercise 5
# For which parameter $\mu,\Sigma,P(C)$ settings is EM clustering identical to k-means clustering and why?<br>
# Mean $\mu_i = \frac{{\sum_{j=1}^{n}{x_j} w_{ij}}}{\sum_{j=1}^{n}{w_{ij}}}$<br>
# Covariance $\Sigma_i = \frac{\sum_{j=1}^{n}w_{ij}(x_j - \mu_i)(x_j - \mu_i)^\top}{\sum_{j=1}^{n} w_{ij}}$<br>
# Prior $P(c_i) = \frac{\sum_{j=1}^{n}w_{ij}}{n}$<br>
#
# When the covarariance matrix is the identity matrix and the prior probabilities are equal for all clusters.

# %% [markdown]
# ## Exercise 6: 2d K-means and gaussian mixture
# Given the two-dimensional points in Table 13.2, assume that $k=2$, and that initially the points are assigned to clusters as follors: $C_1 = \{ x_1, x_2, x_4 \}$ and $C_2 = \{ x_3, x_5 \}$.
# Answer the following questions:
#
# 1. Apply the K-means algorithm until convergence, that is, the clusters do not change, assuming (1) the usual Euclidean distance of the $L_2$-norm as the distance between points, defined as
#
# $$
# ||x_i - x_j||_2 = \sqrt{ \sum_{a=1}^d (x_{ia} - x_{ja})^2 }
# $$
#  and (2) the Manhattan distance of the $L_1$-norm
# $$
# ||x_i - x_j||_1 = \sum_{a=1}^d |x_{ia} - x_{ja}|.
# $$
#
# 2. Apply the EM algorithm with $k=2$ assuming that the dimensions are independent. Show one complete execution of the expectation and the maximization steps. Start with the assumption that $P(C_i | x_{ja}) = 0.5$ for $a=1, 2$ and $j=1, ..., 5$.
#
#
# ![Table 13.2](graphics/13.2.png)

# %%
# Again, if you want, you can use a bit of Python
X = np.array([
    [0, 0, 1.5, 5, 5],
    [2, 0,   0, 0, 2]
]).T # shape [5, 2]

C = [[0, 1, 3], [2, 4]]

k = 2
e = 99
threshold = 0.001
iterations = 3

mu = np.array([np.mean(X[C[idx], ], axis = 0) for idx in range(k)])

for iter in iterations:
    C = [[], []]

    

    print('\nIteration: ', iter)
    print('Means: ', mu)
    print('Clusters: ', C)
    print('Epsilon: ', e)
# Out:
# Iteration:  1
# Means:  [[0.5        0.66666667]
#  [5.         1.        ]]
# Clusters:  [[0, 1, 2], [3, 4]]
# Epsilon:  0.875
#
# Iteration:  2
# Means:  [[0.5        0.66666667]
#  [5.         1.        ]]
# Clusters:  [[0, 1, 2], [3, 4]]
# Epsilon:  0.0

# %%
X = np.array([
    [0, 0, 1.5, 5, 5],
    [2, 0,   0, 0, 2]
]).T # shape [5, 2]

C = [[0, 1, 3], [2, 4]]

k = 2
iter = 0
n, d = X.shape
# Initial parameters:
posterior = np.array([ np.array([ 0.5 for i in range(len(X))]) for j in range(k)]).T

priors = np.array([np.sum(posterior.T[i]) / len(X) for i in range(k)])

mu = np.array([np.sum([x * w for x, w in zip(X, posterior.T[i])], axis = 0) / np.sum(posterior, axis = 0) for i in range(k)])
print(mu)

X_min_mu = np.array([(X[i] - mu) * np.sqrt(posterior[i]) for i in range(len(X)) ])
print(X_min_mu)

#cov = np.array([ np.sum([w*(x - mu_i) @ (x - mu_i).T for x, w, mu_i in zip(X, posterior.T[i], mu[i])], axis = 0) / np.sum(posterior.T[i], axis = 0) for i in range(k) ])
#print(cov)

cov = np.array([ np.sum(X_min_mu @ X_min_mu.T)  / np.sum(posterior) ])
print(cov)


while e > threshold:
    C = [[], []]
    iter += 1
    for idx in range(len(X)):
        c = np.argmin([np.linalg.norm(mu_i - X[idx, ]) for mu_i in mu])
        # c = np.argmin([np.sum(np.abs(mu_i - X[idx, ])) for mu_i in mu]) # Manhattan distance
        C[c].append(idx)

    for idx in range(k):
        mean = np.mean(X[C[idx], ], axis = 0)
        e = np.mean(np.abs(mu[idx] - mean))
        mu[idx] = mean

    print('\nIteration: ', iter)
    print('Means: ', mu)
    print('Covariance: ', cov)
    print('Epsilon: ', e)
# Out:
# [[2.3 0.8]
#  [2.3 0.8]]
# [[[-1.6263456   0.84852814]
#   [-1.6263456   0.84852814]]
#
#  [[-1.6263456  -0.56568542]
#   [-1.6263456  -0.56568542]]
#
#  [[-0.56568542 -0.56568542]
#   [-0.56568542 -0.56568542]]
#
#  [[ 1.90918831 -0.56568542]
#   [ 1.90918831 -0.56568542]]
#
#  [[ 1.90918831  0.84852814]
#   [ 1.90918831  0.84852814]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 25
#      20 print(X_min_mu)
#      22 #cov = np.array([ np.sum([w*(x - mu_i) @ (x - mu_i).T for x, w, mu_i in zip(X, posterior.T[i], mu[i])], axis = 0) / np.sum(posterior.T[i], axis = 0) for i in range(k) ])
#      23 #print(cov)
# ---> 25 cov = np.array([ np.sum(X_min_mu @ X_min_mu.T)  / np.sum(posterior) ])
#      26 print(cov)
#      29 while e > threshold:
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (5,2,2)->(5,newaxis,newaxis) (2,2,5)->(2,newaxis,newaxis)  and requested shape (2,5)

# %% [markdown]
# # Optionals
# ## Exercise 7
# Consider 2D data (2,2), (2,1), (2,3), (1,2), (3,2), (8,2), (8,1), (8,0), (8,3), (8,4), (7,2), (6,2), (9,2), (10,2), (7,1), (7,3), (9,1), (9,3)
#
# ![Data plotted](graphics/two_cluster_dataplot.png)

# %% [markdown]
# 1. let k=2 and sketch visually what you think the final clustering will be and explain why.
# 2. Does the initialization influence the final clustering? And why?

# %% [markdown]
# ## Exercise 8: K-means and the Iris dataset
#
# In this exercise, we will apply K-means to the two 2PC dataset from [Zaki] (and slides from Week 2).
# You may use the code below as inspiration.

# %%
X, y = load_iris_PC()

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].scatter(*(X.T), c=y)
ax[0].set_title("Real clusters")

def kmeans(X, k):
    """
        Arguments:
            k: int specifying number of clusters
            X: numpy array with data
        Returns:
            clusters: Array of indicators (ints) indicating the cluster of each point. Shape: [n,]
    """
    n, d = X.shape
    clusters = None 
    new_clusters = None
    centroids = np.random.randn(k, d) # K clusters of shape d
    
    while clusters is None or (not np.allclose(clusters, new_clusters)):
        clusters = None # TODO assign points to clusters
        centroids = None # TODO reassign centroids
        break # Remove this. It is to prevent you getting an infinite loop if you try to run the code before modifying it
        
    return clusters

clusters = kmeans(X, 3)
ax[1].scatter(*(X.T), c=clusters)
ax[1].set_title("K-means clusters")
plt.show()
# Out:
# C:\Users\au647909\OneDrive - Aarhus universitet\Skrivebord\dm2023-solutions\exercises\utilities/data/iris-PC.txt
